# %% [markdown]
# # 📊 Couche Gold — agg_daily_sales_by_store
#
# ## ➡️ Pour Superset :
#
# - Time-series : évolution CA, marge, panier moyen
# - Classement : top/bottom magasins (par CA, marge, croissance)
# - Alertes : magasins avec n_loss_transactions > 5 ou gross_margin_pct < 0.15

# %% [markdown]
# # 📦 Couche Gold — product_performance_mtd
#
# ## ➡️ Pour Superset :
#
# - Scatter plot : stock_turnover_mtd vs gross_margin_pct_mtd → quadrants (étoiles, vaches à lait, etc.)
# - Top 10 produits par revenue_mtd, gross_profit_mtd, revenue_share_mtd
# - Filtrage par stock_velocity_label → liste d’actions merchandising

# %% [markdown]
# # 👔 Couche Gold — employee_performance
#
# ## ➡️ Pour Superset :
#
# - Classement vendeurs (par CA, marge, panier moyen)
# - Alertes : vendeurs avec n_price_alerts > 0 ou n_loss_transactions > 3
# - Comparaison vs magasin : revenue_percentile par boutique

# %% [markdown]
# # 📅 Couche Gold — daily_kpi_dashboard
#
# ## ➡️ Pour Superset :
#
# - Big numbers : CA hier, marge, variation vs semaine
# - Indicateurs de santé : n_alerts_yesterday, n_loss_transactions_yesterday
# - Automatisation : rafraîchissement quotidien → dashboard “état du jour”
